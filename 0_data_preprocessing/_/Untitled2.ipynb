# %%
import netCDF4

# %%
from pprint import pprint

# %%
with netCDF4.Dataset("/home/research/research/modeling/weather_forecast/tripleclouds/data/raw/3dcorrection_outputs_2020010100_2250c0.nc", "r", format="NETCDF4") as file:
    pprint(list(file.variables.keys()))
    pprint(file.dimensions)
    pprint(file.dimensions['band_sw'].size)
    print(file.dimensions['column'].size)
    print(file['pressure_hl'][:])
# Out:
# ['pressure_hl',
#  'flux_up_lw',
#  'flux_dn_lw',
#  'lw_derivative',
#  'canopy_flux_dn_lw_surf',
#  'flux_up_sw',
#  'flux_dn_sw',
#  'flux_dn_direct_sw',
#  'spectral_flux_dn_sw_surf',
#  'spectral_flux_dn_direct_sw_surf',
#  'canopy_flux_dn_diffuse_sw_surf',
#  'canopy_flux_dn_direct_sw_surf',
#  'cloud_cover_lw',
#  'cloud_cover_sw']
# {'band_sw': <class 'netCDF4._netCDF4.Dimension'>: name = 'band_sw', size = 14,
#  'canopy_band_lw': <class 'netCDF4._netCDF4.Dimension'>: name = 'canopy_band_lw', size = 2,
#  'canopy_band_sw': <class 'netCDF4._netCDF4.Dimension'>: name = 'canopy_band_sw', size = 6,
#  'column': <class 'netCDF4._netCDF4.Dimension'>: name = 'column', size = 16960,
#  'half_level': <class 'netCDF4._netCDF4.Dimension'>: name = 'half_level', size = 138}
# 14
# 16960
# [[0.00000000e+00 2.00036502e+00 3.10224104e+00 ... 9.87079453e+04
#   9.89648438e+04 9.91999375e+04]
#  [0.00000000e+00 2.00036502e+00 3.10224104e+00 ... 9.87353438e+04
#   9.89923125e+04 9.92274766e+04]
#  [0.00000000e+00 2.00036502e+00 3.10224104e+00 ... 9.87710234e+04
#   9.90281016e+04 9.92633359e+04]
#  ...
#  [0.00000000e+00 2.00036502e+00 3.10224104e+00 ... 1.00183789e+05
#   1.00444578e+05 1.00683180e+05]
#  [0.00000000e+00 2.00036502e+00 3.10224104e+00 ... 1.00058922e+05
#   1.00319398e+05 1.00557695e+05]
#  [0.00000000e+00 2.00036502e+00 3.10224104e+00 ... 9.99291562e+04
#   1.00189281e+05 1.00427281e+05]]

# %%
import h5py

with h5py.File("/home/research/research/modeling/weather_forecast/tripleclouds/data/raw/3dcorrection_outputs_2020010100_2250c0.nc", "r") as file:
    pprint(list(file.variables.keys()))
    print(file['pressure_hl'][:])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_3462361/463535060.py in <module>
#       2
#       3 with h5py.File("/home/research/research/modeling/weather_forecast/tripleclouds/data/raw/3dcorrection_outputs_2020010100_2250c0.nc", "r") as file:
# ----> 4     pprint(list(file.variables.keys()))
#       5     print(file['pressure_hl'][:])
#
# AttributeError: 'File' object has no attribute 'variables'

# %%
with netCDF4.Dataset('/home/research/research/modeling/weather_forecast/tripleclouds/data/raw/url-44468da6ed642d5d7d2efee0230090237cc9c14074136cdefdbfa6d58c14c6db.nc', 'r', format='NETCDF4') as file:
    pprint(list(file.variables.keys()))
# Out:
# ['solar_irradiance',
#  'lat',
#  'lon',
#  'skin_temperature',
#  'cos_solar_zenith_angle',
#  'sw_albedo',
#  'sw_albedo_direct',
#  'lw_emissivity',
#  'iseed',
#  'pressure_hl',
#  'temperature_hl',
#  'q',
#  'o3_mmr',
#  'co2_vmr',
#  'n2o_vmr',
#  'ch4_vmr',
#  'o2_vmr',
#  'cfc11_vmr',
#  'cfc12_vmr',
#  'hcfc22_vmr',
#  'ccl4_vmr',
#  'cloud_fraction',
#  'q_liquid',
#  'q_ice',
#  're_liquid',
#  're_ice',
#  'overlap_param',
#  'fractional_std',
#  'inv_cloud_effective_size',
#  'aerosol_mmr']

# %%
solar_irradiance
lat
lon
skin_temperature
cos_solar_zenith_angle
sw_albedo
sw_albedo_direct
lw_emissivity
iseed
pressure_hl
temperature_hl
q
o3_mmr
co2_vmr
n2o_vmr
ch4_vmr
o2_vmr
cfc11_vmr
cfc12_vmr
hcfc22_vmr
ccl4_vmr
cloud_fraction
q_liquid
q_ice
re_liquid
re_ice
overlap_param
fractional_std
inv_cloud_effective_size
aerosol_mmr
flux_dn_sw
flux_up_sw
flux_dn_lw
flux_up_lw
hr_sw
hr_lw

# %%
import os
os.environ['http_proxy'] = 'http://129.183.4.13:8080'
os.environ['https_proxy'] = 'http://129.183.4.13:8080'
os.environ['no_proxy'] = 'yoda,129.183.101.5,172.16.118.13,naboo0,naboo5,nwadmin,172.16.118.137,172.16.118.134'

# %%
import climetlab as cml
import numpy as np 
import matplotlib.pyplot as plt

cml.settings.set("cache-directory", "/home/research/research/modeling/weather_forecast/3dcorrection/data/raw")

cmlds = cml.load_dataset(
    'maelstrom-radiation', 
    dataset='3dcorrection', 
    raw_inputs=False, 
    timestep=list(range(0, 3501, 1000)), 
    minimal_outputs=False,
    patch=list(range(0, 16, 1)),
    hr_units='K d-1',
)
# Out:
# By downloading data from this dataset, you agree to the terms and conditions defined at https://apps.ecmwf.int/datasets/licences/general/ If you do not agree with such terms, do not download the data.
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]

# %%
array = cmlds.to_xarray()

# %%
array
# Out:
# <xarray.Dataset>
# Dimensions:       (column: 1085440, sca_variable: 17, level: 137, col_variable: 27, half_level: 138, hl_variable: 2, p_variable: 1, level_interface: 136, inter_variable: 1)
# Dimensions without coordinates: column, sca_variable, level, col_variable, half_level, hl_variable, p_variable, level_interface, inter_variable
# Data variables: (12/13)
#     sca_inputs    (column, sca_variable) float32 dask.array<chunksize=(16960, 1), meta=np.ndarray>
#     col_inputs    (column, level, col_variable) float32 dask.array<chunksize=(16960, 137, 1), meta=np.ndarray>
#     hl_inputs     (column, half_level, hl_variable) float32 dask.array<chunksize=(16960, 138, 1), meta=np.ndarray>
#     pressure_hl   (column, half_level, p_variable) float32 dask.array<chunksize=(16960, 138, 1), meta=np.ndarray>
#     inter_inputs  (column, level_interface, inter_variable) float32 dask.array<chunksize=(16960, 136, 1), meta=np.ndarray>
#     lat           (column) float32 dask.array<chunksize=(16960,), meta=np.ndarray>
#     ...            ...
#     flux_dn_sw    (column, half_level) float32 dask.array<chunksize=(16960, 138), meta=np.ndarray>
#     flux_up_sw    (column, half_level) float32 dask.array<chunksize=(16960, 138), meta=np.ndarray>
#     flux_dn_lw    (column, half_level) float32 dask.array<chunksize=(16960, 138), meta=np.ndarray>
#     flux_up_lw    (column, half_level) float32 dask.array<chunksize=(16960, 138), meta=np.ndarray>
#     hr_sw         (column, level) float32 dask.array<chunksize=(16960, 137), meta=np.ndarray>
#     hr_lw         (column, level) float32 dask.array<chunksize=(16960, 137), meta=np.ndarray>

# %%
import xarray as xr

# %%
ndarray = array.to_array().to_numpy()
# Out:
# /usr/local/lib/python3.8/site-packages/dask/array/core.py:1636: PerformanceWarning: Increasing number of chunks by factor of 36
#   return da_func(*args, **kwargs)
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# /tmp/ipykernel_3521523/2751260650.py in <module>
# ----> 1 ndarray = array.to_array().to_numpy()
#
# /usr/local/lib/python3.8/site-packages/xarray/core/dataarray.py in to_numpy(self)
#     661         DataArray.data
#     662         """
# --> 663         return self.variable.to_numpy()
#     664
#     665     def as_numpy(self: T_DataArray) -> T_DataArray:
#
# /usr/local/lib/python3.8/site-packages/xarray/core/variable.py in to_numpy(self)
#    1111         # TODO first attempt to call .to_numpy() once some libraries implement it
#    1112         if isinstance(data, dask_array_type):
# -> 1113             data = data.compute()
#    1114         if isinstance(data, cupy_array_type):
#    1115             data = data.get()
#
# /usr/local/lib/python3.8/site-packages/dask/base.py in compute(self, **kwargs)
#     286         dask.base.compute
#     287         """
# --> 288         (result,) = compute(self, traverse=False, **kwargs)
#     289         return result
#     290
#
# /usr/local/lib/python3.8/site-packages/dask/base.py in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     569         postcomputes.append(x.__dask_postcompute__())
#     570
# --> 571     results = schedule(dsk, keys, **kwargs)
#     572     return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#     573
#
# /usr/local/lib/python3.8/site-packages/dask/threaded.py in get(dsk, result, cache, num_workers, pool, **kwargs)
#      77             pool = MultiprocessingPoolExecutor(pool)
#      78
# ---> 79     results = get_async(
#      80         pool.submit,
#      81         pool._max_workers,
#
# /usr/local/lib/python3.8/site-packages/dask/local.py in get_async(submit, num_workers, dsk, result, cache, get_id, rerun_exceptions_locally, pack_exception, raise_exception, callbacks, dumps, loads, chunksize, **kwargs)
#     505                             _execute_task(task, data)  # Re-execute locally
#     506                         else:
# --> 507                             raise_exception(exc, tb)
#     508                     res, worker_id = loads(res_info)
#     509                     state["cache"][key] = res
#
# /usr/local/lib/python3.8/site-packages/dask/local.py in reraise(exc, tb)
#     313     if exc.__traceback__ is not tb:
#     314         raise exc.with_traceback(tb)
# --> 315     raise exc
#     316
#     317
#
# /usr/local/lib/python3.8/site-packages/dask/local.py in execute_task(key, task_info, dumps, loads, get_id, pack_exception)
#     218     try:
#     219         task, data = loads(task_info)
# --> 220         result = _execute_task(task, data)
#     221         id = get_id()
#     222         result = dumps((result, id))
#
# /usr/local/lib/python3.8/site-packages/dask/core.py in _execute_task(arg, cache, dsk)
#     117         # temporaries by their reference count and can execute certain
#     118         # operations in-place.
# --> 119         return func(*(_execute_task(a, cache) for a in args))
#     120     elif not ishashable(arg):
#     121         return arg
#
# /usr/local/lib/python3.8/site-packages/dask/core.py in <genexpr>(.0)
#     117         # temporaries by their reference count and can execute certain
#     118         # operations in-place.
# --> 119         return func(*(_execute_task(a, cache) for a in args))
#     120     elif not ishashable(arg):
#     121         return arg
#
# /usr/local/lib/python3.8/site-packages/dask/core.py in _execute_task(arg, cache, dsk)
#     117         # temporaries by their reference count and can execute certain
#     118         # operations in-place.
# --> 119         return func(*(_execute_task(a, cache) for a in args))
#     120     elif not ishashable(arg):
#     121         return arg
#
# /usr/local/lib/python3.8/site-packages/dask/array/chunk.py in getitem(obj, index)
#     423     try:
#     424         if not result.flags.owndata and obj.size >= 2 * result.size:
# --> 425             result = result.copy()
#     426     except AttributeError:
#     427         pass
#
# MemoryError: Unable to allocate 975. GiB for an array with shape (16960, 6, 137, 1, 138, 1, 1, 136, 1, 1) and data type float32

# %%
import sqlite3
import json

with sqlite3.connect('/home/research/research/modeling/weather_forecast/tripleclouds/data/raw/cache-2.db') as conn:
    cur = conn.execute("""SELECT path, args FROM cache WHERE args LIKE '%inputs%';""")
    rows = cur.fetchall()
    
for row in rows:
    input_path, json_str = row
    url = json.loads(json_str)
    s = url["url"].split("_")
    name = f"outputs_{s[-2]}_{s[-1]}"
    print(name)
    
    with sqlite3.connect('/home/research/research/modeling/weather_forecast/tripleclouds/data/raw/cache-2.db') as conn:
        cur = conn.execute(f"SELECT path FROM cache WHERE args LIKE '%{name}%';")
        output_path = cur.fetchone()[0]
        
    with netCDF4.Dataset(input_path, "r", format="NETCDF4") as file:
        file['pressure_hl'][:]
    break
# Out:
# outputs_2020010100_0c10.nc
# /home/research/research/modeling/weather-forecast/tripleclouds/data/raw/url-947db1276c39c413fef33fc4962cf2e99910d8c2fa53fd2fa5ca90d8e5223545.nc

# %%
3dcorrection_outputs_2020010100_0c0

# %%
import netCDF4
import pprint

with netCDF4.Dataset('/home/research/research/modeling/weather_forecast/tripleclouds/data/raw/url-0b8aff7f923ecea2cda922ad6e094fb7edb4223222a4a981ba9981513987a7f4.nc', 'r', format='NETCDF4') as file:
    pprint.pprint(list(file.variables.keys()))
# Out:
# ['solar_irradiance',
#  'lat',
#  'lon',
#  'skin_temperature',
#  'cos_solar_zenith_angle',
#  'sw_albedo',
#  'sw_albedo_direct',
#  'lw_emissivity',
#  'iseed',
#  'pressure_hl',
#  'temperature_hl',
#  'q',
#  'o3_mmr',
#  'co2_vmr',
#  'n2o_vmr',
#  'ch4_vmr',
#  'o2_vmr',
#  'cfc11_vmr',
#  'cfc12_vmr',
#  'hcfc22_vmr',
#  'ccl4_vmr',
#  'cloud_fraction',
#  'q_liquid',
#  'q_ice',
#  're_liquid',
#  're_ice',
#  'overlap_param',
#  'fractional_std',
#  'inv_cloud_effective_size',
#  'aerosol_mmr']

# %%
import sqlite3
